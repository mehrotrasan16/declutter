# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
from github import Github

# %%
from github import Github
accesstoken = ""
with open("D:/Temp/githubapitest/gitToken.txt") as tokenreader:
    accesstoken = tokenreader.read()
g = Github(accesstoken)
g

# %%
repo = g.get_repo('JabRef/jabref')
repo
# Out:
# Repository(full_name="JabRef/jabref")

# %%
issues = repo.get_issues(state='closed')

# %%
issuearray = []
for issue in issues[:1000]:
    #print(issue)
    issuearray.append(issue)

# %%
issues.totalCount
# Out:
# 6145

# %%
issue.created_at.month
# Out:
# 9

# %%
import matplotlib.pyplot as plt

plt.plot([i.created_at.strftime("%m-%Y") for i in issuearray])

# %%
X = [i.created_at. for i in issuearray]

# %%
Y = [set(X)]
Y
# Out:
# [{datetime.datetime(2019, 9, 1, 21, 37, 17),
#   datetime.datetime(2019, 9, 2, 7, 39, 31),
#   datetime.datetime(2019, 9, 2, 7, 39, 33),
#   datetime.datetime(2019, 9, 2, 7, 39, 34),
#   datetime.datetime(2019, 9, 2, 7, 39, 42),
#   datetime.datetime(2019, 9, 2, 7, 39, 51),
#   datetime.datetime(2019, 9, 2, 7, 39, 52),
#   datetime.datetime(2019, 9, 2, 9, 10, 51),
#   datetime.datetime(2019, 9, 2, 14, 43, 49),
#   datetime.datetime(2019, 9, 2, 16, 31, 23),
#   datetime.datetime(2019, 9, 3, 8, 50, 15),
#   datetime.datetime(2019, 9, 3, 20, 37, 4),
#   datetime.datetime(2019, 9, 3, 20, 52, 17),
#   datetime.datetime(2019, 9, 5, 6, 28, 40),
#   datetime.datetime(2019, 9, 5, 7, 41, 9),
#   datetime.datetime(2019, 9, 5, 11, 35, 47),
#   datetime.datetime(2019, 9, 5, 12, 50, 13),
#   datetime.datetime(2019, 9, 5, 13, 16),
#   datetime.datetime(2019, 9, 5, 21, 31, 16),
#   datetime.datetime(2019, 9, 7, 5, 50, 13),
#   datetime.datetime(2019, 9, 7, 15, 41, 35),
# ...

# %%
issuestartdate = [[i.created_at.month,i.created_at.year] for i in issuearray]

# %%
issuestartdate
# Out:
# [[5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [5, 2020],
#  [4, 2020],
#  [4, 2020],
#  [4, 2020],
#  [4, 2020],
#  [4, 2020],
#  [4, 2020],
#  [4, 2020],
#  [4, 2020],
#  [4, 2020],
#  [4, 2020],
#  [4, 2020],
#  [4, 2020],
#  [4, 2020],
#  [4, 2020],
#  [4, 2020],
#  [4, 2020],
#  [4, 2020],
#  [4, 2020],
#  [4, 2020],
#  [4, 2020],
#  [4, 2020],
#  [4, 2020],
#  [4, 2020],
#  [4, 2020],
#  [4, 2020],
#  [4, 2020],
#  [4, 2020],
# ...

# %%
# Out:
#   File "<ipython-input-54-9fbc0e035d96>", line 1
#     issuestartdate.count((,2019))
#                           ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import pandas as pd

# %%
repo
# Out:
# Repository(full_name="JabRef/jabref")

# %%
commits = repo.get_commits()
print(f'The  number of commits is {(commits.totalCount)}')
# Out:
# The  number of commits is 14833

# %%
comments = repo.get_comments()
print(f'The number of comments is {comments.totalCount}')
# Out:
# The number of comments is 327

# %%
branches = repo.get_branches()
print(f'the number of branches is {branches.totalCount}')
# Out:
# the number of branches is 26

# %%
forks = repo.get_forks()
print(f'the number of forks of this project(including my own) is {forks.totalCount}')
# Out:
# the number of forks of this project(including my own) is 1128

# %%
tags = repo.get_tags()
print(f'the number of tags in JabRef is {tags.totalCount}. Some of them are {[t.name for t in tags[:10]]}')
# Out:
# the number of tags in JabRef is 42. Some of them are ['v5.0', 'v5.0-beta', 'v5.0-alpha', 'v4.3.1', 'v4.3', 'v4.2', 'v4.1', 'v4.0', 'v4.0-beta3', 'v4.0-beta2']

# %%
labels = repo.get_labels()
print(f'the number of labels in Jabrefs issues is {labels.totalCount}. Some of them are {[l.name for l in labels[:10]]}')
# Out:
# the number of labels in Jabrefs issues is 50. Some of them are ['autocompletion', 'biblatex', 'build-system', 'cleanup-ops', 'cli', 'duplicateFinder', 'entry-editor', 'entry-preview', 'export / save', 'external files']

# %%
langs = repo.get_languages()
print(f'the languages used in Jabref are: {[l for l in langs]}')
# Out:
# the languages used in Jabref are: ['Java', 'TeX', 'CSS', 'Python', 'Ruby', 'Groovy', 'Shell', 'XSLT', 'ANTLR', 'PowerShell', 'GAP', 'Batchfile']

# %%
pulls = repo.get_pulls()
print(f'the number of pull requests to Jabref are {pulls.totalCount}.')
# Out:
# the number of pull requests to Jabref are 41.

# %%
stars = repo.get_stargazers_with_dates()
for i in stars[:5]:
    print(i)
# Out:
# Stargazer(user="simonharrer")
# Stargazer(user="karelin")
# Stargazer(user="jrioux")
# Stargazer(user="egonw")
# Stargazer(user="ansell")

# %%
stars[0],stars[0].starred_at
# Out:
# (Stargazer(user="simonharrer"), datetime.datetime(2014, 3, 11, 17, 20, 30))
